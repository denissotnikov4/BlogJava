# %%
# !pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 6.3MB 35.4MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23919 sha256=57b95a8a14d5e013926636e2d94003f8e704ee9140e960eb097811b9a4ac5de1
#   Stored in directory: /root/.cache/pip/wheels/fe/a0/79/b73d4a0c535b421b88fc7b393936b371fabbfeaf979eca4050
# Successfully built yfinance
# ...
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import yfinance as yf
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Your path to data set below
fn = '/content/drive/MyDrive/DataSets/vacancies_2020.csv.gz'
df = pd.read_csv(fn, compression='gzip')
df.head()
# Out:
#          id  ...                                        terms_found
# 0  30711158  ...  jmeter спринт тестировщик continuous_integrati...
# 1  30711538  ...  современный_офис memcache team phpunit php арх...
# 2  30713109  ...                     яндекс windows_7 гибкий_график
# 3  30714567  ...  медицинская_страховка официальное_трудоустройс...
# 4  30716168  ...  bash team c# perl английский_язык тестирование...
#
# [5 rows x 56 columns]

# %%
df.shape
# Out:
# (587637, 56)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587637 entries, 0 to 587636
# Data columns (total 56 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   id                         587637 non-null  int64
#  1   description                587637 non-null  object
#  2   key_skills                 431738 non-null  object
#  3   schedule_id                587637 non-null  object
#  4   schedule_name              587637 non-null  object
#  5   accept_handicapped         587637 non-null  bool
#  6   accept_kids                587637 non-null  bool
#  7   experience_id              587637 non-null  object
#  8   experience_name            587637 non-null  object
#  9   specializations            587637 non-null  object
#  10  contacts                   12130 non-null   object
#  11  billing_type_id            587637 non-null  object
#  12  billing_type_name          587637 non-null  object
# ...

# %%
# Change a boolean value
df["accept_handicapped"]        = df["accept_handicapped"].replace([False, True], [0, 1])
df["accept_kids"]               = df["accept_kids"].replace([False, True], [0, 1])
df["allow_messages"]            = df["allow_messages"].replace([False, True], [0, 1])
df["premium"]                   = df["premium"].replace([False, True], [0, 1])
df["accept_incomplete_resumes"] = df["accept_incomplete_resumes"].replace([False, True], [0, 1])
df["response_letter_required"]  = df["response_letter_required"].replace([False, True], [0, 1])
df["has_test"]                  = df["has_test"].replace([False, True], [0, 1])
df["archived"]                  = df["archived"].replace([False, True], [0, 1])

# %%
# Change a object value
df["employer_trusted"] = df["employer_trusted"].replace([False, True], [0, 1])
df["test_required"]    = df["test_required"].replace([False, True], [0, 1])
df["salary_gross"]     = df["salary_gross"].replace([False, True], [0, 1])

# %%
df = df.rename(columns={'schedule_id': 'schedule', 
                        'experience_id': 'experience',
                        'billing_type_id':'billing_type',
                        'type_id': 'type',
                        'department_id': 'department',
                        'employment_id': 'employment'})

# %%
df = df.drop(columns=['billing_type_name', 'schedule_name', 'experience_name', 
                      'type_name', 'address_street', 'address_building', 
                      'address_description', 'address_lat', 'address_lng', 'address_lng', 'contacts'])

# %%
df = df.drop(columns=['driver_license_types', 'response_url', 
                      'insider_interview', 'code', 'department', 
                      'department_name', 'employment_name'])

# %%
df = df.drop(columns='area_url')

# %%
df = df.drop(columns='created_at')

# %%
df.head()
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
# 1  30711538  ...           2
# 2  30713109  ...           3
# 3  30714567  ...           2
# 4  30716168  ...           2
#
# [5 rows x 38 columns]

# %% [markdown]
# ---
# # Change a Categorical data
# ---

# %% [markdown]
# ---
# ### Label Encoder for the "schedule" column
# *   fullDay = 2
# *   remote = 3
# *   flexible = 0
# *   shift = 4
# *    flyInFlyOut = 1
# ---

# %%
df.schedule.value_counts()
# Out:
# fullDay        450230
# remote          78151
# flexible        38095
# shift           13723
# flyInFlyOut      7438
# Name: schedule, dtype: int64

# %%
display(df[df.schedule == 'fullDay'].head(1))
display(df[df.schedule == 'remote'].head(1))
display(df[df.schedule == 'flexible'].head(1))
display(df[df.schedule == 'shift'].head(1))
display(df[df.schedule == 'flyInFlyOut'].head(1))
# Out:
#          id  ...                                        terms_found
# 0  30711158  ...  jmeter спринт тестировщик continuous_integrati...
#
# [1 rows x 39 columns]
#          id  ...                     terms_found
# 2  30713109  ...  яндекс windows_7 гибкий_график
#
# [1 rows x 39 columns]
#           id  ...                                        terms_found
# 16  33721521  ...  желание_развиваться digital_marketing google_a...
#
# [1 rows x 39 columns]
#           id  ...                                        terms_found
# 33  33725761  ...  team sphinx prometheus mesos nginx php английс...
#
# [1 rows x 39 columns]
#           id  ...  terms_found
# 70  36620016  ...  опыт_работы
#
# [1 rows x 39 columns]

# %%
le = LabelEncoder()
df["schedule"] = le.fit_transform(df["schedule"])

# %%
display(df[df.id == 30711158].head(1)) 
display(df[df.id == 30713109].head(1)) 
display(df[df.id == 33721521].head(1)) 
display(df[df.id == 33725761].head(1)) 
display(df[df.id == 36620016].head(1))
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
#
# [1 rows x 40 columns]
#          id  ... schedule_id
# 2  30713109  ...           3
#
# [1 rows x 40 columns]
#           id  ... schedule_id
# 16  33721521  ...           0
#
# [1 rows x 40 columns]
#           id  ... schedule_id
# 33  33725761  ...           4
#
# [1 rows x 40 columns]
#           id  ... schedule_id
# 70  36620016  ...           1
#
# [1 rows x 40 columns]

# %%
df.head()
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
# 1  30711538  ...           2
# 2  30713109  ...           3
# 3  30714567  ...           2
# 4  30716168  ...           2
#
# [5 rows x 40 columns]

# %% [markdown]
# ---
# ### Label Encoder for the "billing_type" column
# *   standart = 2
# *   standart_plus = 3
# *   free = 0
# *   premium = 1
# ---

# %%
df.billing_type.value_counts()
# Out:
# standard         474034
# standard_plus     93293
# free              18857
# premium            1453
# Name: billing_type, dtype: int64

# %%
display(df[df.billing_type == 'standard'].head(1))
display(df[df.billing_type == 'standard_plus'].head(1))
display(df[df.billing_type == 'free'].head(1))
display(df[df.billing_type == 'premium'].head(1))
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
#
# [1 rows x 40 columns]
#           id  ... schedule_id
# 41  33727380  ...           0
#
# [1 rows x 40 columns]
#           id  ... schedule_id
# 80  36620066  ...           2
#
# [1 rows x 40 columns]
#            id  ... schedule_id
# 981  36628324  ...           3
#
# [1 rows x 40 columns]

# %%
df["billing_type"] = le.fit_transform(df["billing_type"])

# %%
display(df[df.id == 30711158].head(1)) 
display(df[df.id == 33727380].head(1)) 
display(df[df.id == 36620066].head(1)) 
display(df[df.id == 36628324].head(1))
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
#
# [1 rows x 40 columns]
#           id  ... schedule_id
# 41  33727380  ...           0
#
# [1 rows x 40 columns]
#           id  ... schedule_id
# 80  36620066  ...           2
#
# [1 rows x 40 columns]
#            id  ... schedule_id
# 981  36628324  ...           3
#
# [1 rows x 40 columns]

# %% [markdown]
# ---
# ### Label Encoder for the "type" column
# *   open = 2
# *   anonymous = 0
# *   direct = 1
# ---

# %%
df.type.value_counts()
# Out:
# open         585720
# anonymous      1160
# direct          757
# Name: type, dtype: int64

# %%
display(df[df.type == 'open'].head(1))
display(df[df.type == 'anonymous'].head(1))
display(df[df.type == 'direct'].head(1))
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
#
# [1 rows x 40 columns]
#            id  ... schedule_id
# 650  36625405  ...           3
#
# [1 rows x 40 columns]
#             id  ... schedule_id
# 1992  38967368  ...           2
#
# [1 rows x 40 columns]

# %%
df["type"] = le.fit_transform(df["type"])

# %%
display(df[df.id == 30711158].head(1)) 
display(df[df.id == 36625405].head(1)) 
display(df[df.id == 38967368].head(1))
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
#
# [1 rows x 40 columns]
#            id  ... schedule_id
# 650  36625405  ...           3
#
# [1 rows x 40 columns]
#             id  ... schedule_id
# 1992  38967368  ...           2
#
# [1 rows x 40 columns]

# %% [markdown]
# ---
# ### Label Encoder for the "employment" column
# *   full = 0
# *   part = 1
# *   project = 3
# *   probation = 2
# *   volunteer = 4
# ---

# %%
df.employment.value_counts()
# Out:
# full         552948
# part          24922
# project        5090
# probation      4628
# volunteer        49
# Name: employment, dtype: int64

# %%
display(df[df.employment == 'full'].head(1))
display(df[df.employment == 'part'].head(1))
display(df[df.employment == 'project'].head(1))
display(df[df.employment == 'probation'].head(1))
display(df[df.employment == 'volunteer'].head(1))
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
#
# [1 rows x 40 columns]
#          id  ... schedule_id
# 2  30713109  ...           3
#
# [1 rows x 40 columns]
#            id  ... schedule_id
# 248  36621657  ...           3
#
# [1 rows x 40 columns]
#            id  ... schedule_id
# 310  36622495  ...           0
#
# [1 rows x 40 columns]
#              id  ... schedule_id
# 18454  39748244  ...           3
#
# [1 rows x 40 columns]

# %%
df["employment"] = le.fit_transform(df["employment"])

# %%
display(df[df.id == 30711158].head(1)) 
display(df[df.id == 30713109].head(1)) 
display(df[df.id == 36621657].head(1)) 
display(df[df.id == 36622495].head(1)) 
display(df[df.id == 39748244].head(1))
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
#
# [1 rows x 40 columns]
#          id  ... schedule_id
# 2  30713109  ...           3
#
# [1 rows x 40 columns]
#            id  ... schedule_id
# 248  36621657  ...           3
#
# [1 rows x 40 columns]
#            id  ... schedule_id
# 310  36622495  ...           0
#
# [1 rows x 40 columns]
#              id  ... schedule_id
# 18454  39748244  ...           3
#
# [1 rows x 40 columns]

# %% [markdown]
# ---
# ### Label Encoder for the "experience" column
# *   between1And3 = 0
# *   between3And6 = 1
# *   noExperience = 3
# *   moreThan6 = 2
# ---

# %%
df.experience.value_counts()
# Out:
# between1And3    300768
# between3And6    162169
# noExperience    108619
# moreThan6        16081
# Name: experience, dtype: int64

# %%
display(df[df.experience == 'between1And3'].head(1))
display(df[df.experience == 'between3And6'].head(1))
display(df[df.experience == 'noExperience'].head(1))
display(df[df.experience == 'moreThan6'].head(1))
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
#
# [1 rows x 40 columns]
#          id  ... schedule_id
# 8  31364469  ...           2
#
# [1 rows x 40 columns]
#          id  ... schedule_id
# 2  30713109  ...           3
#
# [1 rows x 40 columns]
#          id  ... schedule_id
# 6  31362372  ...           2
#
# [1 rows x 40 columns]

# %%
df["experience"] = le.fit_transform(df["experience"])

# %%
display(df[df.id == 30711158].head(1)) 
display(df[df.id == 31364469].head(1)) 
display(df[df.id == 30713109].head(1)) 
display(df[df.id == 31362372].head(1))
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
#
# [1 rows x 40 columns]
#          id  ... schedule_id
# 8  31364469  ...           2
#
# [1 rows x 40 columns]
#          id  ... schedule_id
# 2  30713109  ...           3
#
# [1 rows x 40 columns]
#          id  ... schedule_id
# 6  31362372  ...           2
#
# [1 rows x 40 columns]

# %%
df.head()
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
# 1  30711538  ...           2
# 2  30713109  ...           3
# 3  30714567  ...           2
# 4  30716168  ...           2
#
# [5 rows x 39 columns]

# %%
df.head()
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
# 1  30711538  ...           2
# 2  30713109  ...           3
# 3  30714567  ...           2
# 4  30716168  ...           2
#
# [5 rows x 39 columns]

# %% [markdown]
# ---
# Format a column "published_at" to format 'YYYY-MM-DD' in code below
# ---

# %%
df["published_at"] = pd.to_datetime(df["published_at"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587637 entries, 0 to 587636
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   id                         587637 non-null  int64
#  1   description                587637 non-null  object
#  2   key_skills                 431738 non-null  object
#  3   schedule                   587637 non-null  int64
#  4   accept_handicapped         587637 non-null  int64
#  5   accept_kids                587637 non-null  int64
#  6   experience                 587637 non-null  int64
#  7   specializations            587637 non-null  object
#  8   billing_type               587637 non-null  int64
#  9   allow_messages             587637 non-null  int64
#  10  premium                    587637 non-null  int64
#  11  accept_incomplete_resumes  587637 non-null  int64
#  12  employer_id                586477 non-null  float64
# ...

# %%
df["published_at"] = df["published_at"].dt.strftime("%Y-%m-%d")

# %%
df.head()
# Out:
#          id  ... schedule_id
# 0  30711158  ...           2
# 1  30711538  ...           2
# 2  30713109  ...           3
# 3  30714567  ...           2
# 4  30716168  ...           2
#
# [5 rows x 38 columns]
